# %%
print("Hello, Cherly! You're now coding in Python with Anaconda 🚀")
# Out:
# Hello, Cherly! You're now coding in Python with Anaconda 🚀

# %%
import pandas as pd

# %%
df = pd.read_csv("uber.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv("uber.csv")
#
# File D:\Downloads\Anaconda\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
df = pd.read_csv("uber.csv")
df.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
df['Base'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Downloads\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Base'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df['Base'].unique()
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])

# %%
df.dtypes
# Out:
# Unnamed: 0                         int64
# key                               object
# fare_amount                      float64
# pickup_datetime      datetime64[ns, UTC]
# pickup_longitude                 float64
# pickup_latitude                  float64
# dropoff_longitude                float64
# dropoff_latitude                 float64
# passenger_count                    int64
# dtype: object

# %%
# Extract useful time-based features
df['year'] = df['pickup_datetime'].dt.year
df['month'] = df['pickup_datetime'].dt.month
df['day'] = df['pickup_datetime'].dt.day
df['dayofweek'] = df['pickup_datetime'].dt.dayofweek  
df['hour'] = df['pickup_datetime'].dt.hour
df['minute'] = df['pickup_datetime'].dt.minute
df['second'] = df['pickup_datetime'].dt.second

# %%
df.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#             pickup_datetime  pickup_longitude  pickup_latitude  \
# 0 2015-05-07 19:52:06+00:00        -73.999817        40.738354
# 1 2009-07-17 20:04:56+00:00        -73.994355        40.728225
# 2 2009-08-24 21:45:00+00:00        -74.005043        40.740770
# 3 2009-06-26 08:22:21+00:00        -73.976124        40.790844
# 4 2014-08-28 17:47:00+00:00        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count  year  month  day  \
# 0         -73.999512         40.723217                1  2015      5    7
# 1         -73.994710         40.750325                1  2009      7   17
# ...

# %%
df.to_csv("cleaned_uber_data.csv", index=False)

# %%
df.describe()
# Out:
#          Unnamed: 0    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967154        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count           year  \
# count      199999.000000     199999.000000    200000.000000  200000.000000
# mean          -72.525292         39.923890         1.684535    2011.742440
# std            13.117408          6.794829         1.385997       1.856397
# ...

# %%
print("Mean:", df['fare_amount'].mean())
print("Median:", df['fare_amount'].median())
print("Mode:", df['fare_amount'].mode()[0])
print("Standard Deviation:", df['fare_amount'].std())
# Out:
# Mean: 11.359955250000002
# Median: 8.5
# Mode: 6.5
# Standard Deviation: 9.901776225068813

# %%
# Quartiles
print("Q1 (25%):", df['fare_amount'].quantile(0.25))
print("Q2 (Median):", df['fare_amount'].quantile(0.50))
print("Q3 (75%):", df['fare_amount'].quantile(0.75))

# Data range
print("Range:", df['fare_amount'].max() - df['fare_amount'].min())
# Out:
# Q1 (25%): 6.0
# Q2 (Median): 8.5
# Q3 (75%): 12.5
# Range: 551.0

# %%
Q1 = df['fare_amount'].quantile(0.25)
Q3 = df['fare_amount'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR


outliers = df[(df['fare_amount'] < lower_bound) | (df['fare_amount'] > upper_bound)]
print("Number of outliers:", outliers.shape[0])
# Out:
# Number of outliers: 17167

# %%
# !pip install matplotlib seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['fare_amount'], bins=50, kde=True)
plt.title('Fare Amount Distribution')
plt.xlabel('Fare Amount ($)')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df[df['fare_amount'] < 100]['fare_amount'], bins=50, kde=True)
plt.title('Fare Distribution (Under $100)')
plt.xlabel('Fare Amount ($)')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
from math import radians, sin, cos, sqrt, atan2


df = pd.read_csv("uber.csv")  


def haversine_distance(lat1, lon1, lat2, lon2):
    R = 6371  # Earth radius in kilometers

    
    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)
    lat1 = radians(lat1)
    lat2 = radians(lat2)

    
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlon / 2) ** 2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    return R * c


df['trip_distance'] = df.apply(lambda row: haversine_distance(
    row['pickup_latitude'],
    row['pickup_longitude'],
    row['dropoff_latitude'],
    row['dropoff_longitude']), axis=1)


df = df[df['trip_distance'] > 0]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='trip_distance', y='fare_amount')
plt.title('Fare Amount vs. Distance Traveled')
plt.xlabel('Distance (km)')
plt.ylabel('Fare Amount ($)')
plt.grid(True)
plt.show()

# %%
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])
df['hour'] = df['pickup_datetime'].dt.hour

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='hour', y='fare_amount')
plt.title('Fare Amount vs. Time of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Fare Amount ($)')
plt.grid(True)
plt.show()

# %%
correlation = df[['fare_amount', 'trip_distance', 'hour', 'passenger_count']].corr()
print(correlation)
# Out:
#                  fare_amount  trip_distance      hour  passenger_count
# fare_amount         1.000000       0.025459 -0.020495         0.011551
# trip_distance       0.025459       1.000000 -0.000620        -0.001504
# hour               -0.020495      -0.000620  1.000000         0.013325
# passenger_count     0.011551      -0.001504  0.013325         1.000000

# %%
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
df.to_csv("enhanced_uber_data.csv", index=False)

# %%
import pandas as pd

# Make sure the pickup datetime is in datetime format
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])

# Extract new time-based features
df['hour'] = df['pickup_datetime'].dt.hour
df['day'] = df['pickup_datetime'].dt.day
df['month'] = df['pickup_datetime'].dt.month

# %%
# Monday=0, Sunday=6
df['day_of_week'] = df['pickup_datetime'].dt.dayofweek

# Optional (to make it more readable)
day_map = {0: 'Monday', 1: 'Tuesday', 2: 'Wednesday', 3: 'Thursday', 
           4: 'Friday', 5: 'Saturday', 6: 'Sunday'}
df['day_name'] = df['day_of_week'].map(day_map)

# %%
def label_peak(hour):
    if 7 <= hour <= 9 or 17 <= hour <= 19:
        return 'Peak'
    else:
        return 'Off-Peak'

df['period'] = df['hour'].apply(label_peak)

# %%
# Ensure correct data types
df['day_name'] = df['day_name'].astype('category')
df['period'] = df['period'].astype('category')

# %%
df.to_csv("enhanced_uber_fare.csv", index=False)
